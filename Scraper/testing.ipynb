# %% [markdown]
# Testing the linkgetter for errors then for performance

# %%
from LinkHandling import linkGetter

# %%
linkgetter=linkGetter.LinkGetter(BaseUrl="https://www.jumia.ma/all-products")

# %%
linkgetter.TertiaryLinks()
# Out:
# ['https://www.jumia.ma/all-products/son-informatique/all-products/',
#  'https://www.jumia.ma/all-products/informatique-media/all-products/',
#  'https://www.jumia.ma/all-products/informatique-dispositifs-securite-du-cable/all-products/',
#  'https://www.jumia.ma/all-products/cables-connections/all-products/',
#  'https://www.jumia.ma/all-products/entretien-informatique/all-products/',
#  'https://www.jumia.ma/all-products/adaptateurs/all-products/',
#  'https://www.jumia.ma/all-products/gaming-graphisme/all-products/',
#  'https://www.jumia.ma/all-products/informatique-accessoires-disque-dur/all-products/',
#  'https://www.jumia.ma/all-products/informatique-dispositifs-entree/all-products/',
#  'https://www.jumia.ma/all-products/claviers-et-souris/all-products/',
#  'https://www.jumia.ma/all-products/informatique-accessoires-carte-memoire/all-products/',
#  'https://www.jumia.ma/all-products/cartes-memoires/all-products/',
# ...
